# %% [markdown]
# # 🦈 Shark Attack Analysis 📊

# %% [markdown]
# ## Libraries

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px
import re
import numpy as np
import squarify 
import calendar
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Functions

# %%
import cleaning as cl
import plot as pt

# %% [markdown]
# _____________

# %% [markdown]
# ## Context & hypotheses

# %% [markdown]
# I'm a consultant and i've been contacted by an international water sports and expereriences company willing to implement a new scuba diving activity. They are very concerned about shark attacks, since a customer from a rival company in the sector was attacked by one and that caused their bankruptcy after no client trust them again following the event. Therefore, they want me to study the safest conditions and locations to deploy their activity according to the data, as well as any other relevant information I can provide them by studying the shark attacks dataset.
#
# **Hypotheses**:
# 1. The most attacks occur in Australia and USA.
# 2. Attacks have been deacreasing in the last decades.
# 3. Attacks tend to happen while the victims were surfing, swimming and generally during unsupervised activites.
# 4. Attacks are more common in summer, given that more activities are conducted at sea.

# %% [markdown]
# _____________

# %% [markdown]
# ## The dataset

# %%
df = pd.read_csv('../Input/attacks.csv', encoding_errors='ignore')

# %% [markdown]
# ### The original dataset

# %% [markdown]
# The 'Global Shark Attacks' dataset (DataFrame below) was retrieved from Kaggle and includes a wide arrange of informations regarding shark attacks, with the earliest registers dating from BC and the last from June 2018. The dataset is composed by 25723 rows and 24 columns, yet, around 19000 rows are empty (i.e. filled with NaNs) and some columns don't provide usefull information for the analysis. It is relevant to note that the dataset had a mark of 5.88 out of 10 on Kaggle, meaning that it required a thourough data cleaning process to transform into a more practical dataset.

# %%
df
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %% [markdown]
# ### Dataset cleaning process

# %% [markdown]
# Some transformations and cleaning techniques were applied to the dataset so as to make it functional to work with. Firstly, useless columns were deleted using `.drop()`:
#
#     columns_to_delete = ["Case Number", "pdf", "href formula", "href", "Case Number.1", "Case Number.2", "original order", "Unnamed: 22", "Unnamed: 23"]
#     df = df.drop(columns_to_delete, axis=1)
#
# Then I checked for rows filled with NaN's and deleted them using the reverse `~` to both `isna()` and `.all()`:
#
#     df = df[~df.isna().all(1)]
#
# Then, all elements in 'Country' were transfored into uppercase so they all had the same format:
#
#     `df['Country'] = df['Country'].str.upper()`
#
# Using RegEx, a pattern was searched in the date column to create a new 'month' column:
#
#     df["Month"] = df.Date.apply(lambda x: "".join(re.findall(r"[A-Za-z]{3}-",x)).replace("-",""))
#
# The right space from the name of the column 'Sex' was stripped as well as from its values. Then the column "Sex " with a space was dropped:
#
#     df['Sex'] = df['Sex '].str.rstrip()
#     df = df.drop("Sex ", axis=1)
#
# Then I looked for elements with two digits in 'Age' to clean the column:
#
#     df['Age'] = df['Age'].dropna().apply(lambda x: re.findall(r"\d{2}",x))
#     df['Age'] = df['Age'].str[0] # Dropping extra values in Age (sometimes more than one in one row
#     df['Age'] = df['Age'].astype(float) #Convert all values into floats so we can later operate with them
#
# Finally, the spaces left and right from the 'Fatal (Y/N)' column were stripped, converted all the elements into uppercase, replaced invalid values by 'UNKNOWN' and filled NaNs with 'UNKNOWN'as well . Then, I creted a new column 'Fatal' and dropped the'Fatal (Y/N)' column:
#
#     df['Fatal (Y/N)'] = df['Fatal (Y/N)'].str.rstrip().str.lstrip().str.upper()
#     df['Fatal (Y/N)'] = df['Fatal (Y/N)'].replace({'M': 'UNKNOWN','2017':'UNKNOWN'}).fillna("UNKNOWN") #dealing with NaNs
#     df['Fatal'] = df['Fatal (Y/N)']
#     df = df.drop("Fatal (Y/N)", axis=1)

# %%
df = cl.clean_df(df)

# %%
df
# Out:
#              Date    Year        Type             Country               Area  \
# 0     25-Jun-2018  2018.0     Boating                 USA         California
# 1     18-Jun-2018  2018.0  Unprovoked                 USA            Georgia
# 2     09-Jun-2018  2018.0     Invalid                 USA             Hawaii
# 3     08-Jun-2018  2018.0  Unprovoked           AUSTRALIA    New South Wales
# 4     04-Jun-2018  2018.0    Provoked              MEXICO             Colima
# ...           ...     ...         ...                 ...                ...
# 6297  Before 1903     0.0  Unprovoked           AUSTRALIA  Western Australia
# 6298  Before 1903     0.0  Unprovoked           AUSTRALIA  Western Australia
# 6299    1900-1905     0.0  Unprovoked                 USA     North Carolina
# 6300    1883-1889     0.0  Unprovoked              PANAMA                NaN
# 6301    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
# ...

# %% [markdown]
# ________________

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# After following and Exploratory Data Analysis approach, the hypotheses have been tested through visualization of the data.

# %% [markdown]
# The first step was to determine the age distribution of the dataset. Thanks to the below violin plot, it can observed the victims were very young, with the mean being 24 years old and the mean 28.

# %%
pt.violin_plot(df)

# %% [markdown]
# ### First hypothesis : The most attacks occur in Australia and USA.

# %% [markdown]
# With a huge difference, the most attacks have occured in the USA and the in Autralia. Both account for 50% of the total. The countplot below equally shows how, apart from these two countries and South Africa, shark attacks are mostly rare events around the globe (i.e. Papua New Guinea, in 4th place, has registered 134 attacks since the beginning of the records)

# %%
pt.attacks_country(df)

# %% [markdown]
# ### Second hypothesis: Attacks have been deacreasing in the last decades given to improvement in safety measures

# %% [markdown]
# The second hypothesis was proven to be false. Observing the lineplot below, the curve of attacks per year has been rising gradually since 1900, with a sharp rise and posterior decline in the 1960s which cannot be explained with the information available.

# %%
pt.lineplot(df)

# %% [markdown]
# ### Third hypothesis: Attacks tend to happen while the victims were surfing, swimming and generally during unsupervised activites.

# %% [markdown]
# The activies with the higher risk are swimming and surfing.

# %%
pt.treemap_plot(df)

# %% [markdown]
# ### Fourth hypothesis: Attacks are more common in summer, given that way more activities are conducted at the sea

# %% [markdown]
# The 4th hypothesis was confirmed to some extent. In the USA most attacks occur between January and July, whilst in Australia, most happen between August to December

# %%
pt.histogram(df)

# %% [markdown]
# ## Conclusions

# %% [markdown]
# In absolute terms, shark attacks are a rare event, with a rate of 47 attacks per year from 1900 to 2018 (see operation below). Yet, it is a risk that must be taken seriously when organizing water activities such as scuba diving immersions.
#
# Therefore, after conducting an analysis of the Shark Attacks database, these are some recomendations to an international water sports and expereriences companyfor increasing the safety of their scuba diving activities:
# 1. In terms of location, try to avoid the **USA, Australia and South Africa**.
#     - They combine for a total of 4146 attacks, that is, almost 66% of the attacks happened in these three countries.
#     - Philipines, Egypt or Croatia could be alternative safer options, but still highly popular touristically speaking
# 2. Shark attacks have been increasing steadily and 2015 was the year in which most attacks were registered with 143. Nevertheless, since that year there was a sharp drop, with 'just' 53 attacks recorded in 2018. Hence, statistically there should not be worry of an increasing in attacks per year.
# 3. Swimming, surfing and fishing are the activities during which more attacks happened. Only 76 attacks ocurred while the victim was scuba diving, which accounts for little over 1% of the attacks. Consequently, it can be stated that it will be safe for the company to implement a scuba diving experience.
# 4. Regarding the months in which attacks are less frequent, if we exclude the countries mentioned in the first bullet point, january to may is the safest period of the year according to the data.

# %%
# Calculate total attacks since 1900
df_year = pd.DataFrame(df['Year'].value_counts())
df_year = df_year[df_year.index>1900]
df_year.sum()
# Out:
# Year    5549
# dtype: int64

# %%
#Divide total attacks by number of years from 1900 to 2018 to obtain the attacks per year in that period. 
df_year.sum()/(2018-1900)
# Out:
# Year    47.025424
# dtype: float64
